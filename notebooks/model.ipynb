# %% [markdown]
# # Text Classification with BERT and Cross-Validation
#
# This notebook implements a text sequence classification model based on BERT with 5-fold cross-validation. The pipeline includes training the model, evaluating it, and saving/loading the best model.

# %%
# Install necessary libraries
# %pip install torch transformers datasets scikit-learn matplotlib pandas tqdm colorama seaborn ipywidgets
# Out:
# Requirement already satisfied: torch in /opt/conda/lib/python3.13/site-packages (2.13.0+cu126)
# Requirement already satisfied: transformers in /opt/conda/lib/python3.13/site-packages (5.17.0)
# Requirement already satisfied: datasets in /opt/conda/lib/python3.13/site-packages (5.0.1)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.13/site-packages (1.9.1)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.13/site-packages (3.11.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.13/site-packages (3.0.5)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.13/site-packages (4.70.0)
# Requirement already satisfied: colorama in /opt/conda/lib/python3.13/site-packages (0.4.6)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.13/site-packages (0.13.2)
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.13/site-packages (8.1.9)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.13/site-packages (from torch) (3.32.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/conda/lib/python3.13/site-packages (from torch) (4.16.0)
# Requirement already satisfied: setuptools>=77.0.3 in /opt/conda/lib/python3.13/site-packages (from torch) (83.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/conda/lib/python3.13/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/conda/lib/python3.13/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.13/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /opt/conda/lib/python3.13/site-packages (from torch) (2026.6.0)
# Requirement already satisfied: cuda-toolkit==12.6.3 in /opt/conda/lib/python3.13/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.6.3; platform_system == "Linux"->torch) (12.6.3)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /opt/conda/lib/python3.13/site-packages (from torch) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /opt/conda/lib/python3.13/site-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /opt/conda/lib/python3.13/site-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.29.3 in /opt/conda/lib/python3.13/site-packages (from torch) (2.29.3)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /opt/conda/lib/python3.13/site-packages (from torch) (3.4.5)
# Requirement already satisfied: triton==3.7.1 in /opt/conda/lib/python3.13/site-packages (from torch) (3.7.1)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1.* in /opt/conda/lib/python3.13/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.6.3; platform_system == "Linux"->torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77.* in /opt/conda/lib/python3.13/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.6.3; platform_system == "Linux"->torch) (12.6.77)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4.* in /opt/conda/lib/python3.13/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.6.3; platform_system == "Linux"->torch) (11.3.0.4)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6.* in /opt/conda/lib/python3.13/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.6.3; platform_system == "Linux"->torch) (1.11.1.6)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80.* in /opt/conda/lib/python3.13/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.6.3; platform_system == "Linux"->torch) (12.6.80)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77.* in /opt/conda/lib/python3.13/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.6.3; platform_system == "Linux"->torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2.* in /opt/conda/lib/python3.13/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.6.3; platform_system == "Linux"->torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2.* in /opt/conda/lib/python3.13/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.6.3; platform_system == "Linux"->torch) (12.5.4.2)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85.* in /opt/conda/lib/python3.13/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.6.3; platform_system == "Linux"->torch) (12.6.85)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.85.* in /opt/conda/lib/python3.13/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.6.3; platform_system == "Linux"->torch) (12.6.85)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77.* in /opt/conda/lib/python3.13/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.6.3; platform_system == "Linux"->torch) (12.6.77)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /opt/conda/lib/python3.13/site-packages (from cuda-bindings<13,>=12.9.4->torch) (1.6.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /opt/conda/lib/python3.13/site-packages (from transformers) (1.31.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.13/site-packages (from transformers) (2.5.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.13/site-packages (from transformers) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.13/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /opt/conda/lib/python3.13/site-packages (from transformers) (2026.9.10)
# Requirement already satisfied: tokenizers<0.24.0,>=0.23.1 in /opt/conda/lib/python3.13/site-packages (from transformers) (0.23.2)
# Requirement already satisfied: typer in /opt/conda/lib/python3.13/site-packages (from transformers) (0.27.2)
# Requirement already satisfied: safetensors>=0.8.0 in /opt/conda/lib/python3.13/site-packages (from transformers) (0.8.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /opt/conda/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (8.5.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /opt/conda/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.14.2)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /opt/conda/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.18)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /opt/conda/lib/python3.13/site-packages (from datasets) (25.0.1)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /opt/conda/lib/python3.13/site-packages (from datasets) (0.4.1)
# Requirement already satisfied: requests>=2.32.2 in /opt/conda/lib/python3.13/site-packages (from datasets) (2.34.2)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.13/site-packages (from datasets) (4.0.1)
# Requirement already satisfied: multiprocess<0.70.20 in /opt/conda/lib/python3.13/site-packages (from datasets) (0.70.19)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.13/site-packages (from fsspec[http]<=2026.6.0,>=2023.1.0->datasets) (3.14.3)
# Requirement already satisfied: scipy>=1.10.0 in /opt/conda/lib/python3.13/site-packages (from scikit-learn) (1.18.1)
# Requirement already satisfied: joblib>=1.4.0 in /opt/conda/lib/python3.13/site-packages (from scikit-learn) (1.6.0)
# Requirement already satisfied: narwhals>=2.0.1 in /opt/conda/lib/python3.13/site-packages (from scikit-learn) (2.26.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /opt/conda/lib/python3.13/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.13/site-packages (from matplotlib) (1.4.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /opt/conda/lib/python3.13/site-packages (from matplotlib) (4.65.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.13/site-packages (from matplotlib) (1.5.1)
# Requirement already satisfied: pillow>=9 in /opt/conda/lib/python3.13/site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /opt/conda/lib/python3.13/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: comm>=0.1.3 in /opt/conda/lib/python3.13/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /opt/conda/lib/python3.13/site-packages (from ipywidgets) (9.15.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/conda/lib/python3.13/site-packages (from ipywidgets) (5.15.1)
# Requirement already satisfied: widgetsnbextension~=4.0.16 in /opt/conda/lib/python3.13/site-packages (from ipywidgets) (4.0.16)
# Requirement already satisfied: jupyterlab_widgets~=3.0.17 in /opt/conda/lib/python3.13/site-packages (from ipywidgets) (3.0.17)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/conda/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/conda/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets) (6.8.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets) (1.24.5)
# Requirement already satisfied: decorator>=5.1.0 in /opt/conda/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /opt/conda/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /opt/conda/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in /opt/conda/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: pexpect>4.6 in /opt/conda/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.53)
# Requirement already satisfied: psutil>=7 in /opt/conda/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in /opt/conda/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in /opt/conda/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth>=0.1.4 in /opt/conda/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.8.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /opt/conda/lib/python3.13/site-packages (from jedi>=0.18.2->ipython>=6.1.0->ipywidgets) (0.8.7)
# Requirement already satisfied: cloudpickle>=3.0 in /opt/conda/lib/python3.13/site-packages (from joblib>=1.4.0->scikit-learn) (3.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.13/site-packages (from pexpect>4.6->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.13/site-packages (from requests>=2.32.2->datasets) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/conda/lib/python3.13/site-packages (from requests>=2.32.2->datasets) (2.7.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.2)
# Requirement already satisfied: pure_eval in /opt/conda/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.13/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.13/site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/conda/lib/python3.13/site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /opt/conda/lib/python3.13/site-packages (from typer->transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/conda/lib/python3.13/site-packages (from typer->transformers) (0.0.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.13/site-packages (from rich>=13.8.0->typer->transformers) (4.2.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import Libraries

# %%
import os
import re
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from colorama import Fore, Style
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import (
    classification_report, 
    confusion_matrix,
    accuracy_score,
    roc_auc_score, 
    ConfusionMatrixDisplay
)
from transformers import BertForSequenceClassification, AutoTokenizer, get_scheduler
from torch.utils.data import DataLoader
from torch.optim import AdamW
from datasets import Dataset

# %% [markdown]
# ## Data Preprocessing

# %%
# Keep training input identical to the text passed to the model by the bot.
_PATTERNS = (
    (re.compile(r"<.*?>"), ""),
    (re.compile(r"!\[.*?\]\(.*?\)"), ""),
    (re.compile(r"\[(.*?)\]\(.*?\)"), r"\1"),
    (re.compile(r"(\*\*|__)(.*?)\1"), r"\2"),
    (re.compile(r"(\*|_)(.*?)\1"), r"\2"),
    (re.compile(r"~~(.*?)~~"), r"\1"),
    (re.compile(r"`{1,2}(.*?)`{1,2}"), r"\1"),
    (re.compile(r"#{1,6}\s*"), ""),
    (re.compile(r">\s*"), ""),
    (re.compile(r"[^a-zA-Zа-яА-ЯёЁ\s]"), ""),
    (re.compile(r"\s+"), " "),
)

def preprocess_text(text: str) -> str:
    """Apply the same text cleaning used by the Telegram bot."""
    for pattern, replacement in _PATTERNS:
        text = pattern.sub(replacement, text)
    return text.strip().lower()

# Loading the data
file_path = "all_channel_posts.csv"  # Provide the path to your CSV file
data = pd.read_csv(file_path)

# Extracting text and category labels
texts = data['text'].fillna('').map(preprocess_text).tolist()
labels = data['category'].tolist()

# Converting labels to numerical identifiers
# unique_labels = list(set(labels)).sort()
unique_labels = ['business', 'it', 'personal', 'other', 'weather', 'gaming', 'finances', 'stuff', 'political', 'advertisement', 'science', 'moscow']
label_to_id = {label: idx for idx, label in enumerate(unique_labels)}
id_to_label = {idx: label for label, idx in label_to_id.items()}
labels = [label_to_id[label] for label in labels]

# Splitting data into training and testing sets
train_texts, test_texts, train_labels, test_labels = train_test_split(
    texts, labels, test_size=0.1, random_state=42, stratify=labels
)

# %% [markdown]
# ## Cross-Validation Setup

# %%
# Setting up cross-validation
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Loading the pre-trained tokenizer and setting up the device
model_name = "DeepPavlov/rubert-base-cased"
tokenizer = AutoTokenizer.from_pretrained(model_name)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %% [markdown]
# ## Tokenization Function

# %%
# Tokenization function
def tokenize_function(examples: dict) -> dict:
    """
    Tokenizes input texts using the pre-trained tokenizer.

    Args:
        examples (dict): A dictionary containing the texts to be tokenized.

    :returns: A dictionary containing tokenized texts.
    """
    return tokenizer(examples["text"], padding="max_length", truncation=True, max_length=128)

# %% [markdown]
# ## Data Preparation for Training and Validation

# %%
# Preparing data for training and validation
def prepare_data(texts: list, labels: list, fold_idx: int, kfold: StratifiedKFold) -> tuple:
    """
    Prepares the training and validation datasets for the given fold iteration.

    :param texts: List of input texts.
    :param labels: List of labels.
    :param fold_idx: Index of the current fold.
    :param kfold: StratifiedKFold object for cross-validation.
    :returns: A tuple containing:
            - train_data: A Dataset object for the training data.
            - val_data: A Dataset object for the validation data.
    """
    train_idx, val_idx = list(kfold.split(texts, labels))[fold_idx]

    train_texts = [texts[i] for i in train_idx]
    train_labels = [labels[i] for i in train_idx]
    val_texts = [texts[i] for i in val_idx]
    val_labels = [labels[i] for i in val_idx]

    train_data = Dataset.from_dict({"text": train_texts, "label": train_labels})
    val_data = Dataset.from_dict({"text": val_texts, "label": val_labels})

    train_data = train_data.map(tokenize_function, batched=True)
    val_data = val_data.map(tokenize_function, batched=True)

    train_data.set_format(type="torch", columns=["input_ids", "attention_mask", "label"])
    val_data.set_format(type="torch", columns=["input_ids", "attention_mask", "label"])

    return train_data, val_data

# %% [markdown]
# ## Model Training Function

# %%
# Model training function
def train_model(model: torch.nn.Module, train_loader: DataLoader, optimizer: torch.optim.Optimizer, scheduler: torch.optim.lr_scheduler.LambdaLR) -> float:
    """
    Trains the model for one epoch.

    :param model: The model to be trained.
    :param train_loader: DataLoader for the training set.
    :param optimizer: The optimizer for the model.
    :param scheduler: Learning rate scheduler.
    :returns: The average loss for the epoch.
    """
    model.train()
    total_loss = 0
    for batch in tqdm(train_loader, desc="Training"):
        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)
        labels = batch["label"].to(device)

        optimizer.zero_grad()
        outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss
        total_loss += loss.item()

        loss.backward()
        optimizer.step()
        scheduler.step()

    avg_loss = total_loss / len(train_loader)
    return avg_loss

# %% [markdown]
# ## Model Evaluation Function

# %%
# Model evaluation function
def evaluate_model(model: torch.nn.Module, val_loader: DataLoader, device: torch.device) -> tuple:
    """
    Evaluates the model on validation data.

    :param model: The model to be evaluated.
    :param val_loader: DataLoader for the validation set.
    :param device: The device (CPU or GPU) on which the model is run.
    :returns: Contains three elements:
            - all_preds: List of predicted labels.
            - all_labels: List of true labels.
            - all_probs: List of predicted probabilities for each class.
    """
    model.eval()
    all_preds = []
    all_labels = []
    all_probs = []
    with torch.no_grad():
        for batch in tqdm(val_loader, desc="Evaluation"):
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            labels = batch["label"].to(device)

            outputs = model(input_ids, attention_mask=attention_mask)
            probs = torch.softmax(outputs.logits, dim=1)
            preds = torch.argmax(outputs.logits, axis=1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            all_probs.extend(probs.cpu().numpy())

    return all_preds, all_labels, all_probs

# %% [markdown]
# ## Preparing Test Data

# %%
# Test data preparation function
def prepare_test_data(texts: list, labels: list) -> Dataset:
    """
    Prepares the test dataset for evaluation.

    :param texts: List of test texts.
    :param labels: List of test labels.
    :returns: The test dataset in a format suitable for DataLoader.
    """
    test_data = Dataset.from_dict({"text": texts, "label": labels})
    test_data = test_data.map(tokenize_function, batched=True)
    test_data.set_format(type="torch", columns=["input_ids", "attention_mask", "label"])
    return test_data

# %% [markdown]
# ## Saving and Loading the Best Model

# %%
# Function to save the best model
def save_model(model_path: str, model: torch.nn.Module, tokenizer: AutoTokenizer) -> None:
    """
    Saves the model and tokenizer to disk.

    :param model_path: Path to the directory where the model and tokenizer will be saved.
    :param model: The trained model.
    :param tokenizer: The tokenizer used with the model.
    """
    model.save_pretrained(model_path)
    tokenizer.save_pretrained(model_path)
    print(f"{Fore.GREEN}Model saved at {Style.RESET_ALL}{model_path}")

# %%
# Function to load the best model
def load_model(model_path: str) -> tuple:
    """
    Loads the saved best model and tokenizer from the specified path.

    :param model_path: Path to the directory containing the saved model and tokenizer.
    :returns: The model and tokenizer, if available, otherwise None.
    """
    if not os.path.exists(model_path):
        raise FileNotFoundError(f"Model path {model_path} does not exist.")
    
    model = BertForSequenceClassification.from_pretrained(model_path)
    tokenizer = AutoTokenizer.from_pretrained(model_path)
    print(f"{Fore.GREEN}Model and tokenizer loaded from {Style.RESET_ALL}{model_path}")
    return model, tokenizer

# %% [markdown]
# ## Main Training Loop

# %%
# Training parameters
epochs = 5
batch_size = 8
learning_rate = 5e-5

# Global variables
best_accuracy = 0.0

# Training loop for each fold in cross-validation
for fold_idx in range(kfold.n_splits):
    print(f"\n{Fore.CYAN}Training fold {Style.RESET_ALL}{fold_idx + 1}")

    # Preparing data for training and validation
    train_data, val_data = prepare_data(train_texts, train_labels, fold_idx, kfold)

    # Loading the model for each fold
    model = BertForSequenceClassification.from_pretrained(model_name, num_labels=12)
    model.to(device)

    # Setting up optimizer and scheduler
    optimizer = AdamW(model.parameters(), lr=learning_rate)
    num_training_steps = epochs * len(train_data) // batch_size
    lr_scheduler = get_scheduler(
        name="linear",
        optimizer=optimizer,
        num_warmup_steps=0,
        num_training_steps=num_training_steps
    )

    # DataLoader for training and validation
    train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_data, batch_size=batch_size)

    # Training the model over several epochs
    for epoch in range(epochs):
        print(f"{Fore.YELLOW}Epoch {Style.RESET_ALL}{epoch + 1}/{epochs}")
        avg_loss = train_model(model, train_loader, optimizer, lr_scheduler)
        print(f"{Fore.RED}Training loss: {Style.RESET_ALL}{avg_loss:.4f}")

    # Evaluating accuracy on validation data
    all_preds, all_labels, _ = evaluate_model(model, val_loader, device)
    accuracy = accuracy_score(all_labels, all_preds)
    print(f"{Fore.MAGENTA}Validation Accuracy: {Style.RESET_ALL}{accuracy:.4f}")

    # Saving the model if accuracy improved
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        save_model("best_model", model, tokenizer)

# Clearing CUDA cache if using GPU
if torch.cuda.is_available():
    torch.cuda.empty_cache()
# Out:
# Training fold 1
# Map:   0%|          | 0/15911 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3978 [00:00<?, ? examples/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: DeepPavlov/rubert-base-cased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.decoder.bias               | UNEXPECTED |
# cls.predictions.decoder.weight             | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Epoch 1/5
# Training:   0%|          | 0/1989 [00:00<?, ?it/s]
# Training loss: 0.9315
# Epoch 2/5
# Training:   0%|          | 0/1989 [00:00<?, ?it/s]
# Training loss: 0.4942
# Epoch 3/5
# Training:   0%|          | 0/1989 [00:00<?, ?it/s]
# Training loss: 0.2371
# Epoch 4/5
# Training:   0%|          | 0/1989 [00:00<?, ?it/s]
# Training loss: 0.0981
# Epoch 5/5
# Training:   0%|          | 0/1989 [00:00<?, ?it/s]
# Training loss: 0.0382
# Оценка:   0%|          | 0/498 [00:00<?, ?it/s]
# Validation Accuracy: 0.7788
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Model saved at best_model
#
# Training fold 2
# Map:   0%|          | 0/15911 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3978 [00:00<?, ? examples/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: DeepPavlov/rubert-base-cased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.decoder.bias               | UNEXPECTED |
# cls.predictions.decoder.weight             | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Epoch 1/5
# Training:   0%|          | 0/1989 [00:00<?, ?it/s]
# Training loss: 0.9732
# Epoch 2/5
# Training:   0%|          | 0/1989 [00:00<?, ?it/s]
# Training loss: 0.5368
# Epoch 3/5
# Training:   0%|          | 0/1989 [00:00<?, ?it/s]
# Training loss: 0.2663
# Epoch 4/5
# Training:   0%|          | 0/1989 [00:00<?, ?it/s]
# Training loss: 0.1177
# Epoch 5/5
# Training:   0%|          | 0/1989 [00:00<?, ?it/s]
# Training loss: 0.0454
# Оценка:   0%|          | 0/498 [00:00<?, ?it/s]
# Validation Accuracy: 0.7725
#
# Training fold 3
# Map:   0%|          | 0/15911 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3978 [00:00<?, ? examples/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: DeepPavlov/rubert-base-cased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.decoder.bias               | UNEXPECTED |
# cls.predictions.decoder.weight             | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Epoch 1/5
# Training:   0%|          | 0/1989 [00:00<?, ?it/s]
# Training loss: 0.9556
# Epoch 2/5
# Training:   0%|          | 0/1989 [00:00<?, ?it/s]
# Training loss: 0.5199
# Epoch 3/5
# Training:   0%|          | 0/1989 [00:00<?, ?it/s]
# Training loss: 0.2455
# Epoch 4/5
# Training:   0%|          | 0/1989 [00:00<?, ?it/s]
# Training loss: 0.0998
# Epoch 5/5
# Training:   0%|          | 0/1989 [00:00<?, ?it/s]
# Training loss: 0.0419
# Оценка:   0%|          | 0/498 [00:00<?, ?it/s]
# Validation Accuracy: 0.7753
#
# Training fold 4
# Map:   0%|          | 0/15911 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3978 [00:00<?, ? examples/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: DeepPavlov/rubert-base-cased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.decoder.bias               | UNEXPECTED |
# cls.predictions.decoder.weight             | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Epoch 1/5
# Training:   0%|          | 0/1989 [00:00<?, ?it/s]
# Training loss: 0.9519
# Epoch 2/5
# Training:   0%|          | 0/1989 [00:00<?, ?it/s]
# Training loss: 0.5163
# Epoch 3/5
# Training:   0%|          | 0/1989 [00:00<?, ?it/s]
# Training loss: 0.2500
# Epoch 4/5
# Training:   0%|          | 0/1989 [00:00<?, ?it/s]
# Training loss: 0.1007
# Epoch 5/5
# Training:   0%|          | 0/1989 [00:00<?, ?it/s]
# Training loss: 0.0429
# Оценка:   0%|          | 0/498 [00:00<?, ?it/s]
# Validation Accuracy: 0.7758
#
# Training fold 5
# Map:   0%|          | 0/15912 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3977 [00:00<?, ? examples/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: DeepPavlov/rubert-base-cased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.decoder.bias               | UNEXPECTED |
# cls.predictions.decoder.weight             | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Epoch 1/5
# Training:   0%|          | 0/1989 [00:00<?, ?it/s]
# Training loss: 0.9566
# Epoch 2/5
# Training:   0%|          | 0/1989 [00:00<?, ?it/s]
# Training loss: 0.5177
# Epoch 3/5
# Training:   0%|          | 0/1989 [00:00<?, ?it/s]
# Training loss: 0.2473
# Epoch 4/5
# Training:   0%|          | 0/1989 [00:00<?, ?it/s]
# Training loss: 0.1140
# Epoch 5/5
# Training:   0%|          | 0/1989 [00:00<?, ?it/s]
# Training loss: 0.0417
# Оценка:   0%|          | 0/498 [00:00<?, ?it/s]
# Validation Accuracy: 0.7843
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Model saved at best_model

# %% [markdown]
# ## Final Evaluation

# %%
# Loading the best model after training
model, tokenizer = load_model("model")
model.to(device)

# Preparing the test dataset for final evaluation
test_data = prepare_test_data(test_texts, test_labels)
test_loader = DataLoader(test_data, batch_size=batch_size)

# Final evaluation on the test set
all_preds, all_labels, all_probs = evaluate_model(model, test_loader, device)
# Out:
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# Model and tokenizer loaded from model
# Map:   0%|          | 0/2210 [00:00<?, ? examples/s]
# Оценка:   0%|          | 0/277 [00:00<?, ?it/s]

# %% [markdown]
# ## Results and Metrics

# %%
# Printing final evaluation results
accuracy = accuracy_score(all_labels, all_preds)
print(f"{Fore.MAGENTA}Test Accuracy: {Style.RESET_ALL}{accuracy:.4f}\n")

# Unique classes present in the test set
present_classes = sorted(set(all_labels))

# Printing classification report
print(f"{Fore.MAGENTA}Classification Report:{Style.RESET_ALL}")
print(classification_report(
    all_labels,
    all_preds,
    labels=present_classes,
    target_names=[id_to_label[idx] for idx in present_classes]
))

if len(set(all_labels)) == len(set(all_preds)):
    all_labels_ovr = np.zeros((len(all_labels), len(unique_labels)))
    for i, label in enumerate(all_labels):
        all_labels_ovr[i][label] = 1

    all_probs = np.array(all_probs)
    roc_auc = roc_auc_score(all_labels_ovr, all_probs, average="macro", multi_class="ovr")
    print(f"{Fore.MAGENTA}Macro-Averaged ROC-AUC: {Style.RESET_ALL}{roc_auc:.4f}")
# Out:
# Test Accuracy: 0.7814
#
# Classification Report:
#                precision    recall  f1-score   support
#
#      business       0.74      0.67      0.70       203
#            it       0.83      0.86      0.84       241
#      personal       0.77      0.70      0.73       339
#         other       0.61      0.66      0.63       333
#       weather       0.84      0.78      0.81        40
#        gaming       0.76      0.81      0.79        52
#      finances       0.81      0.76      0.78       114
#         stuff       0.61      0.69      0.65        61
#     political       0.92      0.92      0.92       463
# advertisement       0.80      0.64      0.71        44
#       science       0.88      0.89      0.88       128
#        moscow       0.75      0.84      0.79       192
#
#      accuracy                           0.78      2210
#     macro avg       0.78      0.77      0.77      2210
#  weighted avg       0.78      0.78      0.78      2210
#
# Macro-Averaged ROC-AUC: 0.9672

# %%
# Generating and displaying the confusion matrix
present_classes = sorted(set(all_labels).union(set(all_preds)))
cm = confusion_matrix(all_labels, all_preds, labels=present_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[id_to_label[idx] for idx in present_classes])

disp.plot(cmap="Blues", xticks_rotation=45)
plt.title("Confusion Matrix")
plt.show()
